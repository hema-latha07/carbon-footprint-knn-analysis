# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("Carbon_Footprint_23UCSA204.csv")

# %%
df["NAME "]=df["NAME "].str.upper()
df.to_csv("Carbon_Footprint_23UCSA204.csv", index=False)

# %%
df.head()
# Out:
#                 NAME   AGE        CommuteMode          RideApps  \
# 0          HEMALATHA     19  Public Transport  Few Times a Week
# 1              HELEN     25  Public Transport  Few Times a Week
# 2               ANNIE    20       Two-wheeler            Rarely
# 3  JANANI VICTORIYAA     20       Two-wheeler            Rarely
# 4           HARINI. T    19  Public Transport            Rarely
#
#   AC Usage(In hrs) Switch Off            Diet Red Meat Consumers  \
# 0        2-4 hours  Sometimes           Mixed              Never
# 1        2-4 hours     Always  Non-vegetarian             Rarely
# 2        4-6 hours     Rarely           Vegan             Rarely
# 3        2-4 hours     Always           Mixed              Never
# 4        2-4 hours  Sometimes  Non-vegetarian              Never
#
#   Online shopping Food Waste   Motivation Sustainable Living   Lifestyle
# 0    Occasionally     Rarely  Environment       Lack of Time     Hectic
# ...

# %%
df.tail()
# Out:
#              NAME   AGE        CommuteMode          RideApps  \
# 72  SRUTHI ABINAYA    19  Public Transport  Few Times a Week
# 73        HARINHI     19       Two-wheeler            Rarely
# 74        G.SWETHA    19  Public Transport            Rarely
# 75          SWETHA    19  Public Transport            Rarely
# 76    VAISHNAVI R     19  Public Transport  Few Times a Week
#
#      AC Usage(In hrs) Switch Off            Diet Red Meat Consumers  \
# 72  More than 6 hours  Sometimes           Mixed             Rarely
# 73          4-6 hours  Sometimes           Mixed              Never
# 74          2-4 hours  Sometimes           Mixed             Rarely
# 75          4-6 hours  Sometimes  Non-vegetarian              Never
# 76                  0     Always           Mixed              Never
#
#    Online shopping Food Waste        Motivation Sustainable Living Lifestyle
# 72      Every Week      Never       Environment       Lack of Time   UNKNOWN
# ...

# %%
df.shape
# Out:
# (77, 13)

# %%
df.isnull().sum()
# Out:
# NAME                  0
# AGE                   0
# CommuteMode           0
# RideApps              0
# AC Usage(In hrs)      0
# Switch Off            0
# Diet                  0
# Red Meat Consumers    0
# Online shopping       0
# Food Waste            0
# Motivation            0
# Sustainable Living    0
# Lifestyle             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# NAME                  76
# AGE                   13
# CommuteMode            5
# RideApps               4
# AC Usage(In hrs)       4
# Switch Off             3
# Diet                   4
# Red Meat Consumers     4
# Online shopping        4
# Food Waste             4
# Motivation             4
# Sustainable Living     4
# Lifestyle             26
# dtype: int64

# %%
df["Lifestyle"]=df["Lifestyle"].fillna(df["Lifestyle"].mode()[0])

# %%
df.isnull().sum()
# Out:
# NAME                  0
# AGE                   0
# CommuteMode           0
# RideApps              0
# AC Usage(In hrs)      0
# Switch Off            0
# Diet                  0
# Red Meat Consumers    0
# Online shopping       0
# Food Waste            0
# Motivation            0
# Sustainable Living    0
# Lifestyle             0
# dtype: int64

# %%
 encoder = LabelEncoder()
 df["AGE "] = encoder.fit_transform(df["AGE "])
 print(df[["AGE "]].head())
# Out:
#    AGE
# 0     3
# 1     7
# 2     4
# 3     4
# 4     3

# %%
 df["CommuteMode"] = encoder.fit_transform(df["CommuteMode"])
 print(df[["CommuteMode"]].head())
# Out:
#    CommuteMode
# 0            2
# 1            2
# 2            3
# 3            3
# 4            2

# %%
df["RideApps"] = encoder.fit_transform(df["RideApps"])
print(df[["RideApps"]].head())
# Out:
#    RideApps
# 0         1
# 1         1
# 2         3
# 3         3
# 4         3

# %%
df["AC Usage(In hrs)"] = encoder.fit_transform(df["AC Usage(In hrs)"])
print(df[["AC Usage(In hrs)"]].head())
# Out:
#    AC Usage(In hrs)
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
df["Switch Off"] = encoder.fit_transform(df["Switch Off"])
print(df[["Switch Off"]].head())
# Out:
#    Switch Off
# 0           2
# 1           0
# 2           1
# 3           0
# 4           2

# %%
df["Diet"] = encoder.fit_transform(df["Diet"])
print(df[["Diet"]].head())
# Out:
#    Diet
# 0     0
# 1     1
# 2     2
# 3     0
# 4     1

# %%
df["Red Meat Consumers"] = encoder.fit_transform(df["Red Meat Consumers"])
print(df[["Red Meat Consumers"]].head())
# Out:
#    Red Meat Consumers
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   2

# %%
df["Online shopping"] = encoder.fit_transform(df["Online shopping"])
print(df[["Online shopping"]].head())
# Out:
#    Online shopping
# 0                2
# 1                3
# 2                3
# 3                2
# 4                2

# %%
df["Food Waste"] = encoder.fit_transform(df["Food Waste"])
print(df[["Food Waste"]].head())
# Out:
#    Food Waste
# 0           2
# 1           2
# 2           3
# 3           3
# 4           2

# %%
df["Motivation"] = encoder.fit_transform(df["Motivation"])
print(df[["Motivation"]].head())
# Out:
#    Motivation
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2

# %%
df["Sustainable Living"] = encoder.fit_transform(df["Sustainable Living"])
print(df[["Sustainable Living"]].head())
# Out:
#    Sustainable Living
# 0                   2
# 1                   1
# 2                   1
# 3                   2
# 4                   2

# %%
df["Lifestyle"] = encoder.fit_transform(df["Lifestyle"])
print(df[["Lifestyle"]].head())
# Out:
#    Lifestyle
# 0         12
# 1         24
# 2          8
# 3         19
# 4         25

# %%
df
# Out:
#                  NAME   AGE   CommuteMode  RideApps  AC Usage(In hrs)  \
# 0           HEMALATHA      3            2         1                 1
# 1               HELEN      7            2         1                 1
# 2                ANNIE     4            3         3                 2
# 3   JANANI VICTORIYAA      4            3         3                 1
# 4            HARINI. T     3            2         3                 1
# ..                 ...   ...          ...       ...               ...
# 72      SRUTHI ABINAYA     3            2         1                 3
# 73            HARINHI      3            3         3                 2
# 74            G.SWETHA     3            2         3                 1
# 75              SWETHA     3            2         3                 2
# 76        VAISHNAVI R      3            2         1                 0
#
#     Switch Off  Diet  Red Meat Consumers  Online shopping  Food Waste  \
# ...

# %%
cr_x = df.iloc[:,[i for i in range(1,df.shape[1]) if i!=11]]
cr_x
# Out:
#     AGE   CommuteMode  RideApps  AC Usage(In hrs)  Switch Off  Diet  \
# 0      3            2         1                 1           2     0
# 1      7            2         1                 1           0     1
# 2      4            3         3                 2           1     2
# 3      4            3         3                 1           0     0
# 4      3            2         3                 1           2     1
# ..   ...          ...       ...               ...         ...   ...
# 72     3            2         1                 3           2     0
# 73     3            3         3                 2           2     0
# 74     3            2         3                 1           2     0
# 75     3            2         3                 2           2     1
# 76     3            2         1                 0           0     0
#
#     Red Meat Consumers  Online shopping  Food Waste  Motivation  Lifestyle
# 0                    2                2           2           1         12
# ...

# %%
cr_y = df.iloc[:,-2]
cr_y
# Out:
# 0     2
# 1     1
# 2     1
# 3     2
# 4     2
#      ..
# 72    2
# 73    0
# 74    1
# 75    2
# 76    0
# Name: Sustainable Living, Length: 77, dtype: int64

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
cr_x_train , cr_x_test ,cr_y_train , cr_y_test = train_test_split(cr_x , cr_y , test_size = .2 , random_state = 101)

# %%
#Classification using knn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6)

# %%
knn.fit(cr_x_train , cr_y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
pred_knn = knn.predict(cr_x_test)
pred_knn
# Out:
# array([2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0])

# %%
from sklearn.metrics import confusion_matrix
tab1 = confusion_matrix(pred_knn , cr_y_test)
tab1
# Out:
# array([[1, 1, 0, 1],
#        [0, 1, 0, 0],
#        [4, 4, 3, 1],
#        [0, 0, 0, 0]])

# %%
tab1.diagonal().sum() / tab1.sum() * 100
# Out:
# np.float64(31.25)

# %%
aa = list() # empty list
for i in range(1,50):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(cr_x_train , cr_y_train)
    pred_knn = knn.predict(cr_x_test)
    tab =confusion_matrix(pred_knn , cr_y_test)
    acc = tab.diagonal().sum() / tab.sum()
    aa.append(acc)

# %%
import matplotlib.pyplot as plt
plt.plot(aa)

# %%
#Classification using DecisionTree
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()

# %%
dtree
# Out:
# DecisionTreeClassifier()

# %%
dtree.fit(cr_x_train,cr_y_train)
# Out:
# DecisionTreeClassifier()

# %%
pre_y = dtree.predict(cr_x_test)

# %%
pre_y
# Out:
# array([3, 0, 0, 2, 2, 0, 2, 2, 3, 1, 1, 2, 2, 2, 2, 2])

# %%
from sklearn import metrics
print(metrics.accuracy_score(cr_y_test,pre_y)*100)
# Out:
# 18.75

# %%
from sklearn.metrics import confusion_matrix
tap = confusion_matrix(pre_y,cr_y_test)
tap
# Out:
# array([[0, 2, 0, 1],
#        [2, 0, 0, 0],
#        [3, 4, 2, 0],
#        [0, 0, 1, 1]])

# %%
from sklearn.metrics import accuracy_score

accuracy_dtree = accuracy_score(cr_y_test, pre_y)
print("Accuracy:", accuracy_dtree)
# Out:
# Accuracy: 0.1875

# %%
from sklearn.metrics import accuracy_score

accuracy_knn = accuracy_score(cr_y_test, pred_knn)
print("Accuracy:", accuracy_knn)
# Out:
# Accuracy: 0.1875

# %%
tap.diagonal().sum()/tap.sum()*100
# Out:
# np.float64(18.75)

# %%
dtree.feature_importances_
# Out:
# array([0.08256852, 0.06544459, 0.09450039, 0.156287  , 0.03937516,
#        0.05889399, 0.06249154, 0.        , 0.16436317, 0.11990674,
#        0.15616889])

# %%
feature_score = pd.DataFrame({"Importance": dtree.feature_importances_,"Variable_name":cr_x_train.columns})
feature_score
# Out:
#     Importance       Variable_name
# 0     0.082569                AGE
# 1     0.065445         CommuteMode
# 2     0.094500            RideApps
# 3     0.156287    AC Usage(In hrs)
# 4     0.039375          Switch Off
# 5     0.058894                Diet
# 6     0.062492  Red Meat Consumers
# 7     0.000000     Online shopping
# 8     0.164363          Food Waste
# 9     0.119907          Motivation
# 10    0.156169           Lifestyle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %%
feature_score.sort_values(['Importance'] , ascending = False )
# Out:
#     Importance       Variable_name
# 8     0.164363          Food Waste
# 3     0.156287    AC Usage(In hrs)
# 10    0.156169           Lifestyle
# 9     0.119907          Motivation
# 2     0.094500            RideApps
# 0     0.082569                AGE
# 1     0.065445         CommuteMode
# 6     0.062492  Red Meat Consumers
# 5     0.058894                Diet
# 4     0.039375          Switch Off
# 7     0.000000     Online shopping

# %%
plt.figure(figsize=(10,6))
plt.barh(feature_score['Variable_name'], feature_score['Importance'], color='pink')
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Feature Importance from Decision Tree')
plt.gca().invert_yaxis() 
plt.show()

# %%
from sklearn.tree import export_text
tree_rules = export_text(dtree, feature_names=cr_x.columns.tolist())
print(tree_rules)
# Out:
# |--- Lifestyle <= 13.50
# |   |--- Lifestyle <= 2.00
# |   |   |--- class: 3
# |   |--- Lifestyle >  2.00
# |   |   |--- Food Waste <= 1.00
# |   |   |   |--- Motivation <= 1.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Motivation >  1.50
# |   |   |   |   |--- Red Meat Consumers <= 1.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- Red Meat Consumers >  1.50
# |   |   |   |   |   |--- class: 3
# |   |   |--- Food Waste >  1.00
# |   |   |   |--- class: 2
# |--- Lifestyle >  13.50
# |   |--- Red Meat Consumers <= 2.50
# |   |   |--- AC Usage(In hrs) <= 1.50
# |   |   |   |--- AC Usage(In hrs) <= 0.50
# |   |   |   |   |--- Lifestyle <= 24.00
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- Lifestyle >  24.00
# |   |   |   |   |   |--- Food Waste <= 2.50
# |   |   |   |   |   |   |--- AGE  <= 3.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- AGE  >  3.50
# |   |   |   |   |   |   |   |--- Switch Off <= 1.00
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plot_tree(dtree, feature_names=cr_x.columns, class_names=True, filled=True)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(aa)

# %%
import numpy as np  
import pandas as pd  
from sklearn.metrics import accuracy_score, f1_score  

#Decision Tree Classifier metrics  
acc_dt = accuracy_score(cr_y_test, pre_y)  
f1_dt = f1_score(cr_y_test, pre_y, average='weighted')  

#KNN Classifier metrics  
acc_knn = accuracy_score(cr_y_test, pred_knn)  
f1_knn = f1_score(cr_y_test, pred_knn, average='weighted')  

#Build comparison table  
comparison_df = pd.DataFrame({  
    'Model': ['Decision Tree', 'KNN'],  
    'Accuracy': [acc_dt, acc_knn],  
    'F1-Score': [f1_dt, f1_knn]  
})  

#Rounded to 2 decimal points for readability  
comparison_df = comparison_df.round(2)  
print(comparison_df)
# Out:
#            Model  Accuracy  F1-Score
# 0  Decision Tree      0.19      0.12
# 1            KNN      0.19      0.06

# %%
model_names = ['Decision Tree', 'k-nearest neighbor']
accuracy_scores = [0.1875, 0.1875]

plt.figure(figsize=(8, 5))
plt.bar(model_names, accuracy_scores, color=['blue', 'black'])
plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.grid(axis='y')
plt.show()

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

#Predict on test data using KNN
pred_knn = knn.predict(cr_x_test)

#Calculate accuracy
knn_acc = accuracy_score(cr_y_test, pred_knn)
print(f"KNN Accuracy: {knn_acc:.2f}")

#Classification report
print("KNN Classification Report:")
print(classification_report(cr_y_test, pred_knn))

#Confusion matrix
cm_knn = confusion_matrix(cr_y_test, pred_knn)
disp_knn = ConfusionMatrixDisplay(confusion_matrix=cm_knn)
disp_knn.plot()
plt.title("KNN Confusion Matrix")
plt.show()
# Out:
# KNN Accuracy: 0.19
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.00      0.00      0.00         6
#            2       0.19      1.00      0.32         3
#            3       0.00      0.00      0.00         2
#
#     accuracy                           0.19        16
#    macro avg       0.05      0.25      0.08        16
# weighted avg       0.04      0.19      0.06        16
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

#Predict on test data using Decision Tree
pre_y = dtree.predict(cr_x_test)

#Calculate accuracy
dtree_acc = accuracy_score(cr_y_test, pre_y)
print(f"Decision Tree Accuracy:  {dtree_acc:.2f}")

#Classification report
print("Decision Tree Classification Report:")
print(classification_report(cr_y_test, pre_y))

#Confusion matrix
cm_dtree = confusion_matrix(cr_y_test, pre_y)
disp_dtree = ConfusionMatrixDisplay(confusion_matrix=cm_dtree)
disp_dtree.plot()
plt.title("Decision Tree Confusion Matrix")
plt.show()
# Out:
# Decision Tree Accuracy:  0.19
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.00      0.00      0.00         6
#            2       0.22      0.67      0.33         3
#            3       0.50      0.50      0.50         2
#
#     accuracy                           0.19        16
#    macro avg       0.18      0.29      0.21        16
# weighted avg       0.10      0.19      0.12        16

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load your dataset
df = pd.read_csv('Carbon_Footprint_23UCSA204.csv')

#Count values in Preference column
preference_counts = df['Sustainable Living'].value_counts()

#Plot bar chart
plt.figure(figsize=(8,6))
preference_counts.plot(kind='bar')
plt.title('Comparison of SustainableLiving')
plt.xlabel('SustainableLiving')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

#Data after normalizing case
preferences = ['Lack of Time', 'Cost', 'Lack of Knowledge', 'Not a priority']
counts = [29, 20, 17, 10]

plt.bar(preferences, counts)
plt.xlabel('SustainableLiving')
plt.ylabel('Count')
plt.title('Comparison of SustainableLiving')
plt.show()
